# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("covid_vaccine_statewise.csv")

# %%
data.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
print(data.groupby("State")[["First Dose Administered"]].sum())
# Out:
#                                           First Dose Administered
# State
# Andaman and Nicobar Islands                          1.642585e+07
# Andhra Pradesh                                       1.232861e+09
# Arunachal Pradesh                                    4.900498e+07
# Assam                                                5.856002e+08
# Bihar                                                1.470503e+09
# Chandigarh                                           4.470310e+07
# Chhattisgarh                                         7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu             3.359506e+07
# Delhi                                                6.243395e+08
# Goa                                                  7.599137e+07
# Gujarat                                              2.131646e+09
# Haryana                                              7.557984e+08
# Himachal Pradesh                                     3.162940e+08
# ...

# %%
print(data.groupby("State")[["Second Dose Administered"]].sum())
# Out:
#                                           Second Dose Administered
# State
# Andaman and Nicobar Islands                           4.118554e+06
# Andhra Pradesh                                        3.588176e+08
# Arunachal Pradesh                                     1.193232e+07
# Assam                                                 1.307888e+08
# Bihar                                                 2.707906e+08
# Chandigarh                                            1.159374e+07
# Chhattisgarh                                          1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu              4.594416e+06
# Delhi                                                 1.882189e+08
# Goa                                                   1.619817e+07
# Gujarat                                               6.004184e+08
# Haryana                                               1.586561e+08
# Himachal Pradesh                                      7.383858e+07
# ...

# %%
first_dose_administered = data.groupby("State")[["First Dose Administered"]].sum()
second_dose_administered = data.groupby("State")[["Second Dose Administered"]].sum()

# %%
plt.figure(figsize=(12,6))
plt.plot(first_dose_administered.index,first_dose_administered["First Dose Administered"],label="First Dose",marker="o")
plt.plot(second_dose_administered.index,second_dose_administered["Second Dose Administered"],label="Second Dose",marker="o")
plt.xlabel("State")
plt.ylabel("Doses Adminitered")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
print(data["Male(Individuals Vaccinated)"].sum())
# Out:
# 7138698858.0

# %%
print(data["Female(Individuals Vaccinated)"].sum())
# Out:
# 6321628736.0

# %%
plt.figure(figsize=(8, 6))
total_male_vaccinated = data["Male(Individuals Vaccinated)"].sum()
total_female_vaccinated = data["Female(Individuals Vaccinated)"].sum()
plt.bar(["Male", "Female"], [total_male_vaccinated, total_female_vaccinated], color=['blue', 'pink'])
# Out:
# <BarContainer object of 2 artists>
